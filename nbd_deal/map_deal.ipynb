# %%
#!/usr/bin/env python3
# -*- encoding: utf-8 -*-
'''
@File    :   map_deal.ipynb
@Time    :   2022/04/19 19:20:43
@Author  :   Bao Mingxi 
@Version :   1.0
@Contact :   baomx1314@163.com
'''

from common_use import *
from crosswalk_deal import *
from junction_deal import *
from lane_deal import *
from signal_deal import *
from overlap_deal import *
from clear_area_deal import *
from speed_bump_deal import *
from road_deal import *
from parking_space_deal import *
from pnc_junction_deal import *
import re 
import matplotlib.pyplot as plt
import json
import os.path as path

# %%
with open("yiqi.txt","r") as f:
    dataS=f.read().replace("\n","").replace(" ","")

    # 处理crosswalk
    # crosswalk_all=dataS[:dataS.find("junction")-1]  #提取crosswalk全部数据
    # crosswalk=crosswalk_all.split("crosswalk")
    # crosswalk.remove("")# 删除了分割第一个产生的空元素
    # # data=crosswalk.pop(-1)
    # crosswalk_deal(crosswalk)     #生成crosswalk文件

    # #处理junction
    # junction_all=dataS[dataS.find("junction"):dataS.find("lane")-1]
    # # print(junction_all[0])
    # junction=junction_all.split("junction")
    # junction.remove("")
    # junction_deal(junction)

    # #处理lane
    # lane_all=dataS[dataS.find("lane"):dataS.find("signal")-1]
    # lane=lane_all.split("}lane{")
    # lane_deal(lane)


    # #处理信号
    # signal_all=dataS[dataS.find("}signal{"):dataS.find("}overlap{")+1:]
    # signal_infos=signal_all.split("}signal{")
    # signal_infos.remove("")
    # signal_deal(signal_infos)


    # #处理overlap
    # overlap_all=dataS[dataS.find("overlap{"):dataS.find("}clear_area{")+1]
    # overlap_infos=overlap_all.split("overlap{")
    # overlap_infos.remove("")
    # overlap_deal(overlap_infos)


    # #处理clear——area
    # clear_area_all=dataS[dataS.find("clear_area{"):dataS.find("}speed_bump{")+1]
    # clear_area_infos=clear_area_all.split("clear_area{")
    # clear_area_infos.remove("")
    # clear_area_deal(clear_area_infos)


    # #处理speed-bump
    # speed_bump_all=dataS[dataS.find("speed_bump{"):dataS.find("}road{")+1]
    # speed_bump_infos=speed_bump_all.split("speed_bump{")
    # speed_bump_infos.remove("")
    # speed_bump_deal(speed_bump_infos)


    # #处理road  615
    # road_all=dataS[dataS.find("road{"):dataS.find("}parking_space{")+1]
    # road_infos=road_all.split("road{")
    # road_infos.remove("")
    # road_deal(road_infos)


    # #处理parking_space  14
    # parking_space_all=dataS[dataS.find("parking_space{"):dataS.find("}pnc_junction{")+1]
    # parking_space_infos=parking_space_all.split("parking_space{")
    # parking_space_infos.remove("")
    # parking_space_deal(parking_space_infos)

    #处理pnc_junction  77
    pnc_junction_all=dataS[dataS.find("pnc_junction{"):]
    pnc_junction_infos=pnc_junction_all.split("pnc_junction{")
    pnc_junction_infos.remove("")
    pnc_junction_deal(pnc_junction_infos)
